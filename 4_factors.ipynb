# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

file = 'data2.csv'
data = pd.read_csv(file)
data.columns = ['weekly_rents_per_bedroom', 'latitude', 'longitude', 'distance_to_CBD', 'bedrooms',]
x = sm.add_constant(data.iloc[:,1:]) #生成自变量
y = data['weekly_rents_per_bedroom'] #生成因变量
model = sm.OLS(y, x) #生成模型
result = model.fit() #模型拟合
result.summary() #模型描述
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     weekly_rents_per_bedroom   R-squared:                       0.068
# Model:                                  OLS   Adj. R-squared:                  0.068
# Method:                       Least Squares   F-statistic:                     1305.
# Date:                      Sun, 29 Aug 2021   Prob (F-statistic):               0.00
# Time:                              01:48:56   Log-Likelihood:            -3.8184e+05
# No. Observations:                     71279   AIC:                         7.637e+05
# Df Residuals:                         71274   BIC:                         7.637e+05
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1204.9123    208.901      5.768      0.000     795.467    1614.357
# latitude          -21.6882      4.054     -5.349      0.000     -29.635     -13.742
# longitude         -31.0502      2.048    -15.162      0.000     -35.064     -27.036
# distance_to_CBD    -0.0020   2.95e-05    -68.468      0.000      -0.002      -0.002
# bedrooms           -1.6418      0.227     -7.219      0.000      -2.088      -1.196
# ==============================================================================
# Omnibus:                    69717.459   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5781745.335
# Skew:                           4.641   Prob(JB):                         0.00
# Kurtosis:                      46.134   Cond. No.                     1.30e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
